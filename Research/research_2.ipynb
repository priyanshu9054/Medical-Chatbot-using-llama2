# %%
# !pip install pinecone
# !pip install pinecone-client
# !pip install langchain
# !pip install langchain-community
# !pip install accelerate
# !pip install CTransformers
# !pip install sentence_transformers
# !pip install pymupdf

from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from langchain.document_loaders import PyMuPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.5/973.5 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.5/308.5 kB 36.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 11.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 6.5 MB/s eta 0:00:00
# ...

# %%
prompt_tempelate="""
Use the following pieces of information to answer the user's question.
If you don't know the answer just say you don't know the answer and don't try to make up an answer.

Context:{context}
Question: {question}

Only return helpful answer below and nothing else.
Helpful answer:
"""

# %%
PROMPT = PromptTemplate(template=prompt_tempelate, input_variables=["context",'question'])
chain_type_kwargs={"prompt":PROMPT}

# %%
llm=CTransformers(model="/content/drive/MyDrive/llama-2-7b-chat.ggmlv3.q8_0.bin",
                  model_type="llama",
                  config={'max_new_tokens':512,
                          'temperature':0.8})

# %%
qa=RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retreiver=docsearch.as_retreiver(search_kwargs={}),
    return_source_documents=True,
    chain_type_kwargs=chain_type_kwargs
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ccce831f16c1> in <cell line: 1>()
#       2     llm=llm,
#       3     chain_type="stuff",
# ----> 4     retreiver=docsearch.as_retreiver(search_kwargs={}),
#       5     return_source_documents=True,
#       6     chain_type_kwargs=chain_type_kwargs
#
# AttributeError: 'list' object has no attribute 'as_retreiver'

# %%
# download embedding model
def download_hugging_face_embedding():
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    return embeddings

# %%
embeddings = download_hugging_face_embedding()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# !pip install langchain

# %%
from langchain.vectorstores import Pinecone
from pinecone import Pinecone

pc = Pinecone(api_key="f1b85353-d127-402d-ac3d-1604f116d6b8")
index = pc.Index("grey")
query_result = embeddings.embed_query("High Fever")

retriever = index.query(
    namespace="grey",
    vector=query_result,
    top_k=2,
    include_values=True,

)

# %%
Question="High Fever"

# %%
retriever.matches[0]['id']
# Out:
# 'mainly in critically ill, hosp. Pts (postop major surgery, TPN, sepsis, trauma, burns,\nopiates, immunosuppression, infxn [eg, CMV, Crypto, Campylobacter, typhoid fever])\nClinical manifestations\n History: RUQ/epigastric pain \x02 radiation to R shoulder/back, nausea, vomiting, fever \n Physical examination: RUQ tenderness, Murphys sign \x04 c RUQ pain and inspiratory\narrest with deep breath during palpation of R subcostal region, \x02 palpable gallbladder'

# %%
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever.matches[0],
    return_source_documents=True,
    chain_type_kwargs=chain_type_kwargs
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-33-a30b7cb4aecf> in <cell line: 1>()
# ----> 1 qa = RetrievalQA.from_chain_type(
#       2     llm=llm,
#       3     chain_type="stuff",
#       4     retriever=retriever.matches[0],
#       5     return_source_documents=True,
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py in from_chain_type(cls, llm, chain_type, chain_type_kwargs, **kwargs)
#     107             llm, chain_type=chain_type, **_chain_type_kwargs
#     108         )
# --> 109         return cls(combine_documents_chain=combine_documents_chain, **kwargs)
#     110
#     111     @abstractmethod
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warn_if_direct_instance(self, *args, **kwargs)
#     181                         warned = True
#     182                         emit_warning()
# ...

# %%
while True:
  user_input=input(f"Input Prompt:")
  result=qa({"query": user_input})
  print("Response :",result['result'])

# %%
def get_llama_response(context,question):
    # Load the Llama2 model
    llm = CTransformers(
        model='/content/drive/MyDrive/llama-2-7b-chat.ggmlv3.q8_0.bin',
        model_type='llama',
        config={'max_new_tokens': 256, 'temperature': 0.01}
    )

    # Define the prompt template
    prompt_tempelate="""
    Use the following pieces of information to answer the user's question.
    If you don't know the answer just say you don't know the answer and don't try to make up an answer.

    Context:{context}
    Question: {question}

    Only return helpful answer below and nothing else.
    Helpful answer:
    """
    PROMPT = PromptTemplate(template=prompt_tempelate, input_variables=["context",'question'])
    # Generate response from llama model
    response = llm.invoke(PROMPT.format(context=context,question=question))

    return response

# %%
response=get_llama_response(retriever.matches[0]['id'],Question)
print(response)
# Out:
#  Yes, a high fever in a critically ill patient can be concerning and may indicate an infection or sepsis. It is important to evaluate the patient thoroughly and consider the potential causes of the fever, such as surgical site infection, pneumonia, or bloodstream infection. The patient's history of recent major surgery and current symptoms of RUQ/epigastric pain, nausea, vomiting, and fever suggest the possibility of an infectious complication. Further evaluation and management by a healthcare provider are necessary to determine the cause of the fever and provide appropriate treatment.
